# %%
from sklearn import tree
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
BOA = pd.read_csv('BAC.csv')
BOA.head()
# Out:
#    Unnamed: 0      Date       Open       High        Low      Close  \
# 0           0  1/2/2019  24.080000  25.139999  24.010000  24.959999
# 1           1  1/3/2019  24.940001  25.040001  24.450001  24.559999
# 2           2  1/4/2019  25.100000  25.650000  25.030001  25.580000
# 3           3  1/7/2019  25.559999  25.780001  25.290001  25.559999
# 4           4  1/8/2019  25.719999  25.790001  25.090000  25.510000
#
#    Adj Close    Volume        P/N  Daily_Change  Daily_%_Change  Future_Change
# 0  24.404781  71836300   Positive           NaN             NaN      -0.400000
# 1  24.013680  66599600  Negative      -0.400000       -1.602564       1.020001
# 2  25.010988  83829100   Positive      1.020001        4.153099      -0.020001
# 3  24.991436  57016300   Positive     -0.020001       -0.078190      -0.049999
# 4  24.942547  67339400   Positive     -0.049999       -0.195614       0.250000

# %%
Tweet = pd.read_csv('TweetSentiment.csv')
Tweet.head()
# Out:
#     tweetdate  compound       neg       neu       pos
# 0  2018-01-01  0.271533  0.116333  0.681667  0.201667
# 1  2018-01-02  0.567400  0.080154  0.709692  0.210231
# 2  2018-01-03  0.113950  0.094750  0.782750  0.122500
# 3  2018-01-04 -0.029990  0.113300  0.779300  0.107300
# 4  2018-01-05 -0.083683  0.072833  0.851667  0.075833

# %%
tweets = pd.DataFrame({
    "Date": Tweet["tweetdate"],
    "Negative Value": Tweet["neg"],
    "Positive Value": Tweet["pos"],
    "Neutral Value": Tweet["neu"],
})
tweets.head()
# Out:
#          Date  Negative Value  Positive Value  Neutral Value
# 0  2018-01-01        0.116333        0.201667       0.681667
# 1  2018-01-02        0.080154        0.210231       0.709692
# 2  2018-01-03        0.094750        0.122500       0.782750
# 3  2018-01-04        0.113300        0.107300       0.779300
# 4  2018-01-05        0.072833        0.075833       0.851667

# %%
tweets['Date'] = pd.to_datetime(tweets['Date'])
tweets.head()
# Out:
#         Date  Negative Value  Positive Value  Neutral Value
# 0 2018-01-01        0.116333        0.201667       0.681667
# 1 2018-01-02        0.080154        0.210231       0.709692
# 2 2018-01-03        0.094750        0.122500       0.782750
# 3 2018-01-04        0.113300        0.107300       0.779300
# 4 2018-01-05        0.072833        0.075833       0.851667

# %%
plt.plot(tweets["Date"], tweets["Positive Value"])
plt.xlabel("Date")
plt.ylabel("Positive Value")
# Out:
# Text(0, 0.5, 'Positive Value')

# %%
boa_df= pd.DataFrame({
    "Date": BOA["Date"],
    "Open Price": BOA["Open"],
    "Day High": BOA["High"],
    "Day Low": BOA["Low"],
    "Close Price": BOA["Close"]
})
boa_df.head()
# Out:
#        Date  Open Price   Day High    Day Low  Close Price
# 0  1/2/2019   24.080000  25.139999  24.010000    24.959999
# 1  1/3/2019   24.940001  25.040001  24.450001    24.559999
# 2  1/4/2019   25.100000  25.650000  25.030001    25.580000
# 3  1/7/2019   25.559999  25.780001  25.290001    25.559999
# 4  1/8/2019   25.719999  25.790001  25.090000    25.510000

# %%
boa_df_new = pd.DataFrame({
    "Date": BOA["Date"],
    "Open Price": BOA["Open"],
    "Day High": BOA["High"],
    "Day Low": BOA["Low"],
    "Close Price": BOA["Close"],
    "P/N": BOA["P/N"]
})
boa_df_new.head()
# Out:
#        Date  Open Price   Day High    Day Low  Close Price        P/N
# 0  1/2/2019   24.080000  25.139999  24.010000    24.959999   Positive
# 1  1/3/2019   24.940001  25.040001  24.450001    24.559999  Negative
# 2  1/4/2019   25.100000  25.650000  25.030001    25.580000   Positive
# 3  1/7/2019   25.559999  25.780001  25.290001    25.559999   Positive
# 4  1/8/2019   25.719999  25.790001  25.090000    25.510000   Positive

# %%
boa_df_new['Date'] = pd.to_datetime(boa_df_new['Date'])
boa_df_new.head()
# Out:
#         Date  Open Price   Day High    Day Low  Close Price        P/N
# 0 2019-01-02   24.080000  25.139999  24.010000    24.959999   Positive
# 1 2019-01-03   24.940001  25.040001  24.450001    24.559999  Negative
# 2 2019-01-04   25.100000  25.650000  25.030001    25.580000   Positive
# 3 2019-01-07   25.559999  25.780001  25.290001    25.559999   Positive
# 4 2019-01-08   25.719999  25.790001  25.090000    25.510000   Positive

# %%
boa_df['Date'] = pd.to_datetime(boa_df['Date'])
boa_df.head()
# Out:
#         Date  Open Price   Day High    Day Low  Close Price
# 0 2019-01-02   24.080000  25.139999  24.010000    24.959999
# 1 2019-01-03   24.940001  25.040001  24.450001    24.559999
# 2 2019-01-04   25.100000  25.650000  25.030001    25.580000
# 3 2019-01-07   25.559999  25.780001  25.290001    25.559999
# 4 2019-01-08   25.719999  25.790001  25.090000    25.510000

# %%
stock_tweets = pd.merge(boa_df_new, tweets, on='Date')
stock_tweets.head()
# Out:
#         Date  Open Price   Day High    Day Low  Close Price        P/N  \
# 0 2019-01-02   24.080000  25.139999  24.010000    24.959999   Positive
# 1 2019-01-03   24.940001  25.040001  24.450001    24.559999  Negative
# 2 2019-01-04   25.100000  25.650000  25.030001    25.580000   Positive
# 3 2019-01-07   25.559999  25.780001  25.290001    25.559999   Positive
# 4 2019-01-08   25.719999  25.790001  25.090000    25.510000   Positive
#
#    Negative Value  Positive Value  Neutral Value
# 0        0.053667        0.191000       0.755333
# 1        0.051000        0.160778       0.788333
# 2        0.033571        0.183429       0.783000
# 3        0.150833        0.117500       0.731667
# 4        0.054200        0.299000       0.646600

# %%
# plt.plot(stock_tweets["Date"], stock_tweets["Close Price"], stock_tweets["Open Price"])
# plt.xlabel("Date")
# plt.ylabel("Close Price")

# %%
boa_open_close = pd.DataFrame({
    "Date": BOA["Date"],
    "Open Price": BOA["Open"],
    "Close Price": BOA["Close"]
})
boa_open_close.head()
# Out:
#        Date  Open Price  Close Price
# 0  1/2/2019   24.080000    24.959999
# 1  1/3/2019   24.940001    24.559999
# 2  1/4/2019   25.100000    25.580000
# 3  1/7/2019   25.559999    25.559999
# 4  1/8/2019   25.719999    25.510000

# %%
boa_high_low= pd.DataFrame({
    "Date": BOA["Date"],
    "Day High": BOA["High"],
    "Day Low": BOA["Low"]
})
boa_high_low.head()
# Out:
#        Date   Day High    Day Low
# 0  1/2/2019  25.139999  24.010000
# 1  1/3/2019  25.040001  24.450001
# 2  1/4/2019  25.650000  25.030001
# 3  1/7/2019  25.780001  25.290001
# 4  1/8/2019  25.790001  25.090000

# %%
# Plot the data to see if a linear trend exists

### BEGIN SOLUTION
plt.plot(BOA["Date"], BOA["Close"], BOA["Open"])
plt.xlabel("Date")
plt.ylabel("Closing Price")

### END SOLUTION
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
plt.plot(BOA["Date"], BOA["High"], BOA["Low"])
plt.xlabel("Date")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
boa_df_new= pd.DataFrame({
    "Date": BOA["Date"],
    "Open Price": BOA["Open"],
    "Day High": BOA["High"],
    "Day Low": BOA["Low"],
    "Close Price": BOA["Close"],
    "Volume": BOA["Volume"]
})
boa_df_new.head()
# Out:
#        Date  Open Price   Day High    Day Low  Close Price    Volume
# 0  1/2/2019   24.080000  25.139999  24.010000    24.959999  71836300
# 1  1/3/2019   24.940001  25.040001  24.450001    24.559999  66599600
# 2  1/4/2019   25.100000  25.650000  25.030001    25.580000  83829100
# 3  1/7/2019   25.559999  25.780001  25.290001    25.559999  57016300
# 4  1/8/2019   25.719999  25.790001  25.090000    25.510000  67339400

# %%
plt.scatter(boa_df_new["Close Price"], boa_df_new["Volume"])
plt.xlabel("Volume")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
stock_tweets.to_csv("Stock Tweets.csv")

# %%
stock_tweets.head(10)
# Out:
#         Date  Open Price   Day High    Day Low  Close Price        P/N  \
# 0 2019-01-02   24.080000  25.139999  24.010000    24.959999   Positive
# 1 2019-01-03   24.940001  25.040001  24.450001    24.559999  Negative
# 2 2019-01-04   25.100000  25.650000  25.030001    25.580000   Positive
# 3 2019-01-07   25.559999  25.780001  25.290001    25.559999   Positive
# 4 2019-01-08   25.719999  25.790001  25.090000    25.510000   Positive
# 5 2019-01-09   25.670000  25.850000  25.389999    25.760000   Positive
# 6 2019-01-10   25.559999  25.780001  25.420000    25.730000   Positive
# 7 2019-01-11   25.530001  26.040001  25.459999    26.030001   Positive
# 8 2019-01-14   25.770000  26.480000  25.610001    26.370001   Positive
# 9 2019-01-15   26.209999  26.809999  26.049999    26.549999   Positive
#
#    Negative Value  Positive Value  Neutral Value
# 0        0.053667        0.191000       0.755333
# 1        0.051000        0.160778       0.788333
# ...

# %% [markdown]
# Random Forest

# %%
df = pd.read_csv("Stock Tweets.csv")
df.head()
# Out:
#    Unnamed: 0        Date  Open Price   Day High    Day Low  Close Price  \
# 0           0  2019-01-02   24.080000  25.139999  24.010000    24.959999
# 1           1  2019-01-03   24.940001  25.040001  24.450001    24.559999
# 2           2  2019-01-04   25.100000  25.650000  25.030001    25.580000
# 3           3  2019-01-07   25.559999  25.780001  25.290001    25.559999
# 4           4  2019-01-08   25.719999  25.790001  25.090000    25.510000
#
#          P/N  Negative Value  Positive Value  Neutral Value
# 0   Positive        0.053667        0.191000       0.755333
# 1  Negative         0.051000        0.160778       0.788333
# 2   Positive        0.033571        0.183429       0.783000
# 3   Positive        0.150833        0.117500       0.731667
# 4   Positive        0.054200        0.299000       0.646600

# %%
target = df["P/N"]
target_names = ["negative", "positive"]

# %%
data = df.drop(["Date", "P/N", "Unnamed: 0"], axis=1)
feature_names = data.columns
data.head()
# Out:
#    Open Price   Day High    Day Low  Close Price  Negative Value  \
# 0   24.080000  25.139999  24.010000    24.959999        0.053667
# 1   24.940001  25.040001  24.450001    24.559999        0.051000
# 2   25.100000  25.650000  25.030001    25.580000        0.033571
# 3   25.559999  25.780001  25.290001    25.559999        0.150833
# 4   25.719999  25.790001  25.090000    25.510000        0.054200
#
#    Positive Value  Neutral Value
# 0        0.191000       0.755333
# 1        0.160778       0.788333
# 2        0.183429       0.783000
# 3        0.117500       0.731667
# 4        0.299000       0.646600

# %%
# df['DataFrame Column'] = pd.to_numeric(df['DataFrame Column'],errors='coerce')

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=252)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5396825396825397

# %%
from sklearn.metrics import accuracy_score
print('Correct Prediction (%): ', accuracy_score(y_test, rf.predict(X_test), normalize=True)*100.0)
# Out:
# Correct Prediction (%):  53.96825396825397

# %%
from sklearn import model_selection# random forest model creation
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)# predictions
rfc_predict = rfc.predict(X_test)
rfc_predict
# Out:
# /Users/kevinluttrell/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# array(['Negative ', 'Negative ', 'Negative ', 'Positive', 'Positive',
#        'Negative ', 'Positive', 'Negative ', 'Negative ', 'Negative ',
#        'Positive', 'Positive', 'Negative ', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Negative ', 'Negative ', 'Negative ', 'Positive', 'Negative ',
#        'Negative ', 'Negative ', 'Negative ', 'Negative ', 'Negative ',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Negative ',
#        'Negative ', 'Positive', 'Negative ', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Negative ', 'Negative ', 'Positive',
#        'Positive', 'Negative ', 'Positive', 'Positive', 'Negative ',
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
rfc_cv_score = cross_val_score(rfc, X_test, y_test, cv=10, scoring='roc_auc')

# %%
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, rfc_predict))
print('\n')
print("=== Classification Report ===")
print(classification_report(y_test, rfc_predict))
print('\n')
print("=== All AUC Scores ===")
print(rfc_cv_score)
print('\n')
print("=== Mean AUC Score ===")
print("Mean AUC Score - Random Forest: ", rfc_cv_score.mean())
# Out:
# === Confusion Matrix ===
# [[13 11]
#  [16 23]]
#
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#    Negative        0.45      0.54      0.49        24
#     Positive       0.68      0.59      0.63        39
#
#     accuracy                           0.57        63
#    macro avg       0.56      0.57      0.56        63
# weighted avg       0.59      0.57      0.58        63
#
#
#
# === All AUC Scores ===
# [0.41666667 0.45833333 0.70833333 0.75       0.5625     0.25
#  0.25       0.4375     0.4375     0.91666667]
#
#
# === Mean AUC Score ===
# Mean AUC Score - Random Forest:  0.51875
