# 20  2018-02-01  0.332067  0.087333  0.772667  0.140333
# 21  2018-02-02  0.505833  0.081667  0.742667  0.175500
# 22  2018-02-05  0.073314  0.112714  0.676857  0.210429
# 23  2018-02-06 -0.106220  0.135600  0.744200  0.120400
# 24  2018-02-07  0.769857  0.016000  0.663857  0.320143
# 25  2018-02-08  0.615460  0.000000  0.812200  0.187800
# 26  2018-02-09  0.081275  0.085500  0.811000  0.103500
# 27  2018-02-12  0.291167  0.119333  0.695000  0.185667
# 28  2018-02-13  0.283150  0.053000  0.812000  0.135000
# 29  2018-02-14  0.129725  0.095000  0.765750  0.139250
# 30  2018-02-15 -0.304243  0.197286  0.665286  0.137429
# ..         ...       ...       ...       ...       ...
# 469 2019-11-15  0.063147  0.047070  0.888698  0.064186
# 470 2019-11-18  0.019714  0.078214  0.825429  0.096357
# 471 2019-11-19 -0.084718  0.095579  0.862184  0.042263
# 472 2019-11-20  0.063819  0.081351  0.766324  0.152243
# 473 2019-11-21 -0.031617  0.069714  0.850400  0.079857
# 474 2019-11-22  0.032380  0.062900  0.862100  0.075000
# 475 2019-11-25  0.454609  0.000000  0.780000  0.220000
# 476 2019-11-26  0.026148  0.071560  0.812280  0.116080
# 477 2019-11-27  0.267455  0.056182  0.678818  0.265000
# 478 2019-11-29  0.245033  0.000000  0.902667  0.097333
# 479 2019-12-02  0.333434  0.053200  0.793886  0.152857
# 480 2019-12-03  0.144212  0.065667  0.740909  0.193455
# 481 2019-12-04  0.053184  0.071387  0.835613  0.092935
# 482 2019-12-05  0.230200  0.071240  0.732280  0.196520
# 483 2019-12-06 -0.123488  0.087346  0.861308  0.051231
# 484 2019-12-09  0.043339  0.110556  0.744500  0.144944
# 485 2019-12-10  0.274000  0.081854  0.727250  0.190875
# 486 2019-12-11  0.051914  0.082872  0.806833  0.110282
# 487 2019-12-12 -0.039629  0.112018  0.769875  0.118089
# 488 2019-12-13  0.029130  0.119200  0.742633  0.138200
# 489 2019-12-16  0.070019  0.075586  0.772741  0.151672
# 490 2019-12-17  0.454859  0.092471  0.687647  0.220000
# 491 2019-12-18 -0.007625  0.093453  0.774868  0.131679
# 492 2019-12-19  0.006565  0.081296  0.809272  0.109432
# 493 2019-12-20  0.200985  0.055951  0.802293  0.141780
# 494 2019-12-23 -0.134832  0.101000  0.793071  0.105964
# 495 2019-12-24  0.077975  0.046625  0.867875  0.085438
# 496 2019-12-26 -0.476648  0.177333  0.750762  0.072000
# 497 2019-12-27  0.223210  0.053655  0.759966  0.186345
# 498 2019-12-30 -0.007067  0.109667  0.765333  0.125000
#
# [498 rows x 16 columns]

# %%
df = merged_df[['neg', 'neu', 'pos', 'P/N']]
df.head()
# Out:
#         neg       neu       pos       P/N
# 0  0.080154  0.709692  0.210231  Positive
# 1  0.094750  0.782750  0.122500  Positive
# 2  0.113300  0.779300  0.107300  Positive
# 3  0.072833  0.851667  0.075833  Positive
# 4  0.062143  0.839000  0.099000  Positive

# %%
from sklearn.preprocessing import LabelEncoder
# One Hot encoding
# Step 0: Reformat data
data = df.values
X = data[:, 0:3]
y = data[:, 3]

# # Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
from keras.utils import to_categorical

# Step 2: One-hot encoding
one_hot_y = to_categorical(encoded_y)
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split
# splitting data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, one_hot_y)

# %%
clf = RandomForestClassifier(random_state=100)

# %%
# Create the model on train dataset
model = clf.fit(X_train, y_train)
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.metrics import accuracy_score
print('Correct Prediction (%): ', accuracy_score(y_test, model.predict(X_test), normalize=True)*100.0)
# Out:
# Correct Prediction (%):  52.800000000000004

# %%
model.score(X_train, y_train)
# Out:
# 0.952

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.33021569, 0.35031824, 0.31946607])

# %%
sorted(zip(model.feature_importances_, df['P/N']), reverse=True)
# Out:
# [(0.35031824133684275, 'Positive'),
#  (0.33021568845132376, 'Positive'),
#  (0.3194660702118335, 'Positive')]

# %%
# Run the code to view the classification report metrics
from sklearn.metrics import classification_report
report = classification_report(y_test, model.predict(X_test))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.43      0.49        60
#            1       0.62      0.62      0.62        65
#
#    micro avg       0.59      0.53      0.56       125
#    macro avg       0.58      0.52      0.55       125
# weighted avg       0.59      0.53      0.55       125
#  samples avg       0.53      0.53      0.53       125
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %%
merged_df = merged_df.rename(columns={'Daily_%_Change': 'Perc_Change'})

# %%
merged_df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2018-01-02  86.129997  86.309998  85.500000  85.949997  83.256378  22483800
# 1 2018-01-03  86.059998  86.510002  85.970001  86.349998  83.643845  26061400
# 2 2018-01-04  86.589996  87.660004  86.570000  87.110001  84.380028  21912000
# 3 2018-01-05  87.660004  88.410004  87.430000  88.190002  85.426178  23407100
# 4 2018-01-08  88.199997  88.580002  87.599998  88.279999  85.513359  22113000
#
#         P/N  Daily_Change  Perc_Change  Future_Change  tweetdate  compound  \
# 0  Positive           NaN          NaN       0.400001 2018-01-02  0.567400
# 1  Positive      0.400001     0.465388       0.760003 2018-01-03  0.113950
# 2  Positive      0.760003     0.880142       1.080001 2018-01-04 -0.029990
# 3  Positive      1.080001     1.239813       0.089997 2018-01-05 -0.083683
# 4  Positive      0.089997     0.102049      -0.059998 2018-01-08  0.169057
#
#         neg       neu       pos
# 0  0.080154  0.709692  0.210231
# 1  0.094750  0.782750  0.122500
# 2  0.113300  0.779300  0.107300
# 3  0.072833  0.851667  0.075833
# 4  0.062143  0.839000  0.099000

# %%
Ser = pd.Series(model.predict(X).ravel())

# %%
merged_df['strategy_returns'] = merged_df.Perc_Change.shift(-1)* Ser

# %%
dataset_length = merged_df.shape[0]

split = int(dataset_length * 0.75)
split
# Out:
# 375

# %%
merged_df.strategy_returns[split:].hist()
plt.xlabel('Strategy returns (%)')
plt.ylabel('Iteration')
plt.title('Daily Returns Histogram')
plt.savefig("img/MSFT_daily_returns.svg", format="svg")
plt.show()

# %%
# The output displays the strategy returns and daily returns according to the code for the Random Forest Classifier.
x = merged_df.Date
y = merged_df.strategy_returns
plt.plot(x,y)
plt.title('Strategy Returns Per Date')
plt.ylabel('Strategy returns (%)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.savefig("img/MSFT_strategy_returns.png", format="png")
plt.show()

# %%
(merged_df.strategy_returns[split:]+1).cumprod().plot()
plt.ylabel('Strategy returns (%)')
plt.show()

# %%
# save the model to disk
filename = 'MSFT_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.528
